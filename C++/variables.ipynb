// %% [markdown]
// # Переменные, ввод, вывод

// %% [markdown]
// Каждая программа в с++ состоит из частей: библиотеки, пространство имен,  функция main(), код
// по крайне менее пока что это все части. Давайте посмотрим на програмку и поделим ее на части:

// %%
#include <iostream>// библиотека iostream исп. для вывода и ввода данных в программу
#include </*здесь название какой-либо библиотеки*/>

// %% [markdown]
// Такие штуки называются библиотеками, как их делать и что в них лежит будем разбираться гараздо позже, но если вкратце в них находится код, который используется для работы различных функций. К примеру функция cin<<(ввод данных в программу) это сложное действие которое умный программист до нас расписал кодом, и запихнул эту кучу кода в одно слово cin. Смотрим дальше:

// %%
using namespace std;

// %% [markdown]
// Следующее предложение будет для умников и умниц, эту инфу знать пока не очень обязательно. Пространство имен используется как группа, в которых лежат функции, которые пренадлежат только этой группе. К примеру вы хотите создать файлы hi.txt и hi.txt на рабочем столе, компьютер вам не разрешит, ведь они названы одиннаково, поэтому вы кладете первый hi.txt в папку под названием std, а второй hi.txt в папку lol, std и lol это и есть ваши пространства имен.

// %% [markdown]
// Пространство имен либо задается в самом начале строчкой using namespace 'названия' либо перед каждой функцией нужно писать 'название пространства'::'функция', так для функции cout в пространстве имен std мы будем писать std::cout<<

// %%
int main() //начало нашей программы
{
    int x; //создадим переменную x, в которой будем хранить ТОЛЬКО целое ЧИСЛО
    float y; //создадим переменную y, в которой будем хранить ЧИСЛО с плавающей точкой, типо такого 5.6

// %% [markdown]
// На самом деле типов данных в С++ естественно не два, но тут остановимся на этих двух братах акробатах. int 'название переменной' так создается переменная, что означает что в этой букве мы будем хранить какое-либо число.

// %%
cin >> x >> y; //введем с клавиатуры сначала x а потом y
cout << x << y; //выведем их на экран

// %% [markdown]
// cin и cout это функции (о знакомое слово, было в самом начале), таким образом мы создали два "места" где мы будем хранить наши числа, написали с клавиатуры эти самые числа, и затем вывели. Если после запуска программы написать 3 и 2.5, на экране увидем 32.5, почему они так слиплись? потому что компьютер выводит то, что мы ему написали, он буквально выводит сначала x и потом y, чтобы между ними появился пробел нужно буквально его туда написать, вот так: cout<< x <<"  "<< y; Вообще в " " можно выводить любые слова типо: cout<<"Hello world!";

// %% [markdown]
// Мы кстати с переменными можем делать всё тоже что из математики: +, -, *, /,%, предпоследнее это целочисленное деление, тоесть 4/2 ответ 2, 3/2 ответ 1; % это остаток от деления, так 5 % 2 ответ 1. Вот полная программа которая использует все эти операции:

// %%
#include <iostream>
using namespace std;
int main(){
    int x,y; #переменные одного типа можно задавать через запятую
    float q = 2.4; #если мы не хотим вводить значение с клавиатуры, мы можем его сразу задать при объявлении переменной
    cin >> x >> y;
    cout <<"x + y =" << x + y << " x - y =" << x - y << " x * y = " << x * y << " x / y =" << x / y << " x % y = "<<x % y;
    cout <<"x + q =" << x + q << " x - q =" << x - q << " x * q = " << x * q << " x / q =" << x / q<< " x % q= "<<x % q;
    cout << x + y * x + y / 2; //в cout можно писать длинные операции типо таких
}

// %% [markdown]
// О боже что такое, я только что взял целое число x и умножил и прибавил его и тд к float q, что же будет? предлагаю взять эту прогу и запустить самостоятельно. PS всё что написано в кавычках, это буквальный текст который выведет компьютер, тоесть "x - y" это буквально x - y, а без кавычек, это уже операция

// %% [markdown]
// # Лабы на понимание
// 1. Написать программу, которая получает на вход 2 целых числа h и a – высоту и основание треугольника. Рассчитать площадь треугольника.
// 2. Написать программу, которая вернет остаток от деления на 2, чисел вводимых с клавиатуры
// 3. Написать программу, которая получает стороны A, B и C треугольника, определить существует ли такой треугольник или нет.
// 4. Написать программу, которая получает на вход секунды, расчитать минуты, часы
